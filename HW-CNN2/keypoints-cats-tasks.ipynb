# %% [markdown]
# # Домашнее задание 2 - Локализация ключевых точек
# <br>
#
# Задание выполнил(а): Зосимов Савва Орестьевич
# <br>
#
# **Дедлайн:** 26.04.2021 23:59
#
#
# ### О задании
# В этом задании вы познакомитесь с функционалом SAS для реализации сетей локализации ключевых точек, а так же построите и обучите такую сеть самостоятельно.
# <br>
#
# **Задание построено следующим образом:**<br>
# 1) Задание 1: Загрузка данных в CAS - 1 балл<br>
# 2) Задание 2: Соединение таблиц - 3 балла<br>
# 3) Задание 3: Подготовка данных для обучения - 2 балла<br>
# 4) Задание 4: Построение модели - 4 балла<br>
# 5) Задание 5: Обучение модели - 2 балла<br>
# 6) Задание 6: Проверка и визуализация результатов работы сети - 3 балла<br>
# 7) Задание 7 (дополнительное) - до +2 баллов
#
# ### Формат сдачи
#
# После того, как вы выполните домашную работу, поместите jupyter notebook с выполнеными заданиями (output всех ячеек должен сохранится) в закрытый git-репозиторий на GitHub. Предоставьте доступ к репозиторию аккаунтам GazizovMarat и Ala1s (добавив в свой репозиторий в качестве коллабораторов).
#
# ### Важно
# Для того, чтобы ваши результаты были воспроизводимыми для проверки, указывайте seed при вызове методов, где это возможно. Напоминания об этом так же содержатся в тексте заданий.

# %%
import os
import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

from glob import glob
from tqdm import tqdm

from swat import *
from dlpy import Model, Sequential

from dlpy.layers import *
from dlpy.images import ImageTable
from dlpy.splitting import three_way_split

# %% [markdown]
# **Подключение к серверу CAS**<br>
# Подключитесь к серверу CAS под своим логином и паролем.<br>
# Загрузите следующие Action Sets: 'image' и 'deepLearn'.<br>

# %%
#os.environ['CAS_CLIENT_SSL_CA_LIST'] = r"/tmp/4fix/trustedcerts.pem"

# Создаем новую сессию CAS:
# Ваш код здесь
s = CAS('tiger.cs.msu.ru', 5570, username='msu95', password='DarWin##D4')
# Загружаем action sets:
# Ваш код здесь
s.loadactionset('image')
s.loadactionset('deepLearn')
# Out:
# NOTE: Added action set 'image'.
# NOTE: Added action set 'deepLearn'.
# [actionset]
#
#  'deepLearn'
#
# + Elapsed: 0.00902s, user: 0.00114s, sys: 0.00715s, mem: 0.252mb

# %% [markdown]
# **Набор данных**<br>
# Вам предлагается набор данных с фотографиями кошек. Сами фотографии располагаются в папке images. Для каждой фотографии имеется разметка, содержащяя координаты 9 ключевых точек мордочки кошки, точки в разметке представлены через пробел в следующем порядке:
# - Number of points (default is 9)
# - Left Eye
# - Right Eye
# - Mouth
# - Left Ear-1
# - Left Ear-2
# - Left Ear-3
# - Right Ear-1
# - Right Ear-2
# - Right Ear-3
#
# <br>
# Пример изображения:<br>
#
# ![cat](cat1.PNG)
#
# <br>
# Первое число - количество точек, оно нам не потребуется.<br>
# Разметка для каждого изображения находится в отдельном файле, все эти файлы с разметкой содержатся в папке points. Название каждого такого файла совпадает с названием изображения, но имеют расширение '.cat', но не переживайте - это простые текстовые файлы. <br>
# Пример:<br>
# Название файла изображения - 00000001_000.jpg <br>
# Название файла с разметкой - 00000001_000.jpg.cat

# %% [markdown]
# **Задание 1: Загрузка данных в CAS**<br><br>
# a) Перед тем, как использовать набор данных, потребуется решить несколько проблем с ним. <br><br>
# Во-первых, для того чтобы загрузить разметку в CAS потребуется сформировать из них таблицу. Дополните код ниже, чтобы сделать это. <br><br>
# Заметьте, что одна из строчек кода, уже написанного за вас, помогает отсеивать разметку, в которой не все ключевые точки присутствуют на изображении - в таком случае в разметке присутствуют отрицательные числа. Такие примеры нам не потребуются, поэтому код, сохраняющий разметку для изображений, напишите внутри этого блока if.

# %%
points_data = []
a_path = '/var/home/msu95/SAS-CV-2020-Homework2/cats/points/*.cat' #Пропишите здесь путь к папке с аннотациями
for path in glob(a_path):
    with open(path,'r') as f:
        points = f.read().split(' ')[1:-1]
        points = [int(x) for x in points]
        if any(x<0 for x in points) == False:
            #Ваш код здесь
            keypoints_1d = np.array(points[0:]) 
            keypoints_xy = keypoints_1d.reshape((-1, 18))
            keypoints_list = keypoints_xy.tolist()
            filename = os.path.basename(f.name)[:-4]
            keypoints_list[0].insert(0,filename)
            points_data.extend(keypoints_list)
print(points_data)
# Out:
# [['00000001_000.jpg', 175, 160, 239, 162, 199, 199, 149, 121, 137, 78, 166, 93, 281, 101, 312, 96, 296, 133], ['00000001_008.jpg', 318, 222, 340, 224, 327, 238, 301, 199, 304, 182, 321, 196, 341, 197, 359, 183, 361, 203], ['00000001_011.jpg', 167, 173, 242, 185, 191, 247, 112, 105, 118, 0, 171, 74, 270, 90, 353, 35, 332, 147], ['00000001_012.jpg', 115, 122, 179, 121, 133, 169, 95, 70, 93, 17, 131, 46, 233, 39, 281, 9, 224, 69], ['00000001_016.jpg', 375, 263, 436, 260, 409, 296, 332, 226, 319, 157, 363, 186, 439, 179, 472, 146, 475, 215], ['00000001_017.jpg', 410, 464, 511, 344, 568, 494, 222, 473, 113, 370, 288, 359, 380, 250, 337, 75, 476, 200], ['00000001_020.jpg', 225, 125, 337, 139, 250, 200, 186, 93, 169, 12, 237, 60, 360, 79, 462, 51, 411, 124], ['00000001_024.jpg', 278, 121, 347, 121, 317, 179, 228, 79, 220, 12, 282, 61, 339, 60, 397, 16, 387, 76], ['00000001_027.jpg', 229, 142, 273, 147, 247, 171, 210, 109, 197, 85, 230, 98, 291, 103, 327, 80, 301, 116], ['00000001_029.jpg', 377, 113, 442, 112, 411, 165, 343, 70, 327, 5, 378, 40, 435, 40, 469, 7, 473, 70], ['00000002_001.jpg', 371, 449, 605, 460, 461, 665, 265, 281, 122, 33, 384, 161, 667, 170, 932, 6, 711, 300], ['00000002_008.jpg', 187, 185, 295, 186, 271, 284, 87, 158, 80, 3, 176, 95, 267, 98, 348, 39, 315, 160], ['00000002_026.jpg', 153, 160, 205, 157, 182, 202, 117, 140, 109, 81, 150, 114, 198, 111, 235, 73, 235, 131], ['00000003_007.jpg', 329, 116, 400, 116, 373, 180, 277
# %%
labels = ['_filename_0',
'left_eye_x','left_eye_y',
'right_eye_x','right_eye_y',
'mouth_x','mouth_y',
'left_ear1_x','left_ear1_y',
'left_ear2_x','left_ear2_y',
'left_ear3_x','left_ear3_y',
'right_ear1_x','right_ear1_y',
'right_ear2_x','right_ear2_y',
'right_ear3_x','right_ear3_y']

# %%
data = pd.DataFrame.from_records(points_data, columns = labels) 
# Ваш код здесь
print(data.loc[data['_filename_0'] == '60001365_021.jpg'])
data.tail(25)
# Out:
# Empty DataFrame
# Columns: [_filename_0, left_eye_x, left_eye_y, right_eye_x, right_eye_y, mouth_x, mouth_y, left_ear1_x, left_ear1_y, left_ear2_x, left_ear2_y, left_ear3_x, left_ear3_y, right_ear1_x, right_ear1_y, right_ear2_x, right_ear2_y, right_ear3_x, right_ear3_y]
# Index: []
#            _filename_0  left_eye_x  left_eye_y  right_eye_x  right_eye_y  \
# 8980  60001496_008.jpg         186         161          253          179
# 8981  60001496_009.jpg         136          94          192           92
# 8982  60001496_010.jpg         149         142          216          139
# 8983  60001496_012.jpg         237         189          327          225
# 8984  60001496_013.jpg         222         219          329          222
# 8985  60001496_016.jpg         277         201          379          209
# 8986  60001496_021.jpg         130         209          161          213
# 8987  60001496_024.jpg         759         128          849          129
# 8988  60001496_029.jpg         419         324          581          322
# 8989  60001497_018.jpg         225         569          352          535
# 8990  60001497_020.jpg         311         159          337          229
# 8991  60001497_021.jpg         289         128          371          147
# 8992  60001498_000.jpg         219         108          255          102
# 8993  60001498_003.jpg         217         202          277          205
# 8994  60001498_009.jpg         259         160          313          147
# 8995  60001498_013.jpg         117         166          156          165
# 8996  60001498_015.jpg         147         241          254          251
# 8997  60001498_017.jpg         116         224          214          220
# 8998  60001498_020.jpg         206         260          225          260
# 8999  60001498_025.jpg         174         241          272          240
# 9000  60001499_003.jpg         311         133          364          136
# 9001  60001499_008.jpg         497         322          563          324
# 9002  60001499_017.jpg         178         174          213          181
# 9003  60001499_021.jpg         256         131          288          131
# 9004  60001499_024.jpg         178         333          227          336
#
#       mouth_x  mouth_y  left_ear1_x  left_ear1_y  left_ear2_x  left_ear2_y  \
# 8980      193      215          173          132          192           46
# 8981      167      122          103           95          100           30
# 8982      188      196          102          113           99           33
# 8983      273      292          154          122          213            0
# 8984      271      310          103          123          109            9
# 8985      321      293          234          144          228           50
# 8986      141      233          113          191          120          153
# 8987      808      182          699          120          688           21
# 8988      501      454          259          250          243           19
# 8989      316      665          159          438           36          311
# 8990      285      212          326          101          391           66
# 8991      322      163          258           66          269            9
# 8992      242      132          185           92          180           44
# 8993      248      246          171          172          171           91
# 8994      287      206          225          142          200           72
# 8995      138      196           95          154           88          100
# 8996      191      335           79          171           84           37
# 8997      156      306           59          145           44           25
# 8998      215      274          194          252          194          228
# 8999      228      309          137          148           54          101
# 9000      333      186          286           96          267           45
# 9001      551      367          409          300          393          218
# 9002      190      204          152          154          160          109
# 9003      274      158          246          106          235           83
# 9004      200      375          151          300          152          252
#
#       left_ear3_x  left_ear3_y  right_ear1_x  right_ear1_y  right_ear2_x  \
# 8980          221          114           278           131           345
# 8981          138           61           183            61           215
# 8982          153           80           201            78           251
# 8983          251           91           333           129           411
# 8984          186           70           354            78           441
# 8985          297          112           366           119           444
# 8986          138          178           162           182           188
# 8987          758           71           839            73           916
# 8988          395          150           564           152           728
# 8989          192          364           339           328           449
# 8990          383          128           405           199           458
# 8991          303           52           390            75           446
# 8992          213           68           247            61           273
# 8993          216          137           276           140           321
# 8994          256          103           296            94           337
# 8995          118          127           151           126           181
# 8996          170          121           250           131           357
# 8997          137           98           203            98           285
# 8998          209          243           222           243           238
# 8999          159          129           246           127           345
# 9000          315           62           377            66           417
# 9001          450          254           533           258           587
# 9002          186          141           216           147           253
# 9003          259           97           290            97           318
# 9004          185          289           222           291           260
#
#       right_ear2_y  right_ear3_x  right_ear3_y
# 8980            96           322           177
# 8981            27           220            91
# 8982            29           249           108
# 8983            97           356           208
# 8984            12           382           132
# 8985            56           423           162
# 8986           164           185           203
# 8987            27           894           124
# 8988            48           675           248
# 8989           228           353           392
# 8990           238           379           252
# 8991            46           427           110
# 8992            31           279            73
# 8993           104           313           178
# 8994            38           355           114
# 8995            98           181           152
# 8996            76           322           200
# 8997            32           287           142
# 8998           228           238           252
# 8999            48           330           148
# 9000            49           406           105
# 9001           227           581           306
# 9002           129           242           173
# 9003            80           292           106
# 9004           257           253           306

# %% [markdown]
# b) Также, все координаты ключевых точек указаны в абсолютных коорданатах - соотвественно, если мы изменим размер изображения, координаты ключевых точек придётся пересчитывать. Давайте переведем их в относительные координаты - для этого потребуется поделить координаты по x на ширину изображения, а координаты по y на высоту изображения. Обратите внимание, что все изображения различного размера. Также обратите внимание на тип данных столбцов в dataframe - если тип целочисленный, то посчитанные вами значения будут округляться к нулю или единице, что, конечно же, неверно.

# %%
# Ваш код здесь
filenames = data['_filename_0'].tolist()
path = '/var/home/msu95/SAS-CV-2020-Homework2/cats/images/'
path += '% s'
filenames = [path % i for i in filenames]
#print(filenames)
sizes = [[cv2.imread(filename).shape[0],cv2.imread(filename).shape[1]] for filename in filenames]
heights, widths = map(list,zip(*sizes))
#images = list(map(lambda x: cv2.imread(x),filenames))
#heights = list(map(lambda h: h.shape[0], images ))
#widths = list(map(lambda w: w.shape[1], images ))
for column in data.columns[1:]:
    if (column[len(column)-1] == 'y'):        
        data[column] /= heights
    elif (column[len(column)-1] == 'x'):
        data[column] /= widths
data.head(10)
#print(data.loc[data['_filename_0']=='00000338_013.jpg'])
# Out:
#         _filename_0  left_eye_x  left_eye_y  right_eye_x  right_eye_y  \
# 0  00000001_000.jpg    0.466667    0.320000     0.637333     0.324000
# 1  00000001_008.jpg    0.636000    0.592000     0.680000     0.597333
# 2  00000001_011.jpg    0.334000    0.461333     0.484000     0.493333
# 3  00000001_012.jpg    0.230000    0.366366     0.358000     0.363363
# 4  00000001_016.jpg    0.366211    0.386197     0.425781     0.381791
# 5  00000001_017.jpg    0.400391    0.551069     0.499023     0.408551
# 6  00000001_020.jpg    0.450000    0.333333     0.674000     0.370667
# 7  00000001_024.jpg    0.556000    0.363363     0.694000     0.363363
# 8  00000001_027.jpg    0.458000    0.426426     0.546000     0.441441
# 9  00000001_029.jpg    0.754000    0.276961     0.884000     0.274510
#
#     mouth_x   mouth_y  left_ear1_x  left_ear1_y  left_ear2_x  left_ear2_y  \
# 0  0.530667  0.398000     0.397333     0.242000     0.365333     0.156000
# 1  0.654000  0.634667     0.602000     0.530667     0.608000     0.485333
# 2  0.382000  0.658667     0.224000     0.280000     0.236000     0.000000
# 3  0.266000  0.507508     0.190000     0.210210     0.186000     0.051051
# 4  0.399414  0.434655     0.324219     0.331865     0.311523     0.230543
# 5  0.554688  0.586698     0.216797     0.561758     0.110352     0.439430
# 6  0.500000  0.533333     0.372000     0.248000     0.338000     0.032000
# 7  0.634000  0.537538     0.456000     0.237237     0.440000     0.036036
# 8  0.494000  0.513514     0.420000     0.327327     0.394000     0.255255
# 9  0.822000  0.404412     0.686000     0.171569     0.654000     0.012255
#
#    left_ear3_x  left_ear3_y  right_ear1_x  right_ear1_y  right_ear2_x  \
# 0     0.442667     0.186000      0.749333      0.202000      0.832000
# 1     0.642000     0.522667      0.682000      0.525333      0.718000
# 2     0.342000     0.197333      0.540000      0.240000      0.706000
# 3     0.262000     0.138138      0.466000      0.117117      0.562000
# 4     0.354492     0.273128      0.428711      0.262849      0.460938
# 5     0.281250     0.426366      0.371094      0.296912      0.329102
# 6     0.474000     0.160000      0.720000      0.210667      0.924000
# 7     0.564000     0.183183      0.678000      0.180180      0.794000
# 8     0.460000     0.294294      0.582000      0.309309      0.654000
# 9     0.756000     0.098039      0.870000      0.098039      0.938000
#
#    right_ear2_y  right_ear3_x  right_ear3_y
# 0      0.192000      0.789333      0.266000
# 1      0.488000      0.722000      0.541333
# 2      0.093333      0.664000      0.392000
# 3      0.027027      0.448000      0.207207
# 4      0.214391      0.463867      0.315712
# 5      0.089074      0.464844      0.237530
# 6      0.136000      0.822000      0.330667
# 7      0.048048      0.774000      0.228228
# 8      0.240240      0.602000      0.348348
# 9      0.017157      0.946000      0.171569

# %% [markdown]
# c) Сохраните набор данных в формате csv, а затем загрузите эту таблицу в CAS с помощью функции upload_file.

# %%
# Ваш код здесь
data.to_csv('kp2.csv')
points_table = s.upload_file('kp2.csv')
# Out:
# NOTE: Cloud Analytic Services made the uploaded file available as table KP2 in caslib CASUSER(msu95).
# NOTE: The table KP2 has been created in caslib CASUSER(msu95) from binary data uploaded to Cloud Analytic Services.

# %% [markdown]
# d) Создайте список названий переменных, в которых лежат координаты ключевых точек - он нам понадобится в дальнейшем.

# %%
# Ваш код здесь
keypoints_names = labels[1:]
print(keypoints_names)
# Out:
# ['left_eye_x', 'left_eye_y', 'right_eye_x', 'right_eye_y', 'mouth_x', 'mouth_y', 'left_ear1_x', 'left_ear1_y', 'left_ear2_x', 'left_ear2_y', 'left_ear3_x', 'left_ear3_y', 'right_ear1_x', 'right_ear1_y', 'right_ear2_x', 'right_ear2_y', 'right_ear3_x', 'right_ear3_y']

# %% [markdown]
# e) Загрузите изображения из папки images в ImageTable.

# %%
# Ваш код здесь
images = ImageTable.load_files(s,path ='/var/home/msu95/SAS-CV-2020-Homework2/cats/images/')
images.show(20, randomize = False)
images.head(10)
# Out:
# Selected Rows from Table IMAGEDATA_HJYHQR
#
#                                              _image_ _label_  \
# 0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 2  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 3  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 4  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 5  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 6  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 7  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 9  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
#
#         _filename_0  _id_
# 0  00000041_000.jpg   310
# 1  00000344_017.jpg   965
# 2  00000088_025.jpg   602
# 3  00000344_019.jpg   966
# 4  00000041_001.jpg   311
# 5  00000344_020.jpg   967
# 6  00000344_024.jpg   968
# 7  00000041_003.jpg   312
# 8  00000041_007.jpg   313
# 9  00000344_026.jpg   969

# %% [markdown]
# **Задание 2: Соединение таблиц**<br><br>
# a) Соедините таблицу с изображениями и таблицу с казметкой с помощью action dlJoin.
# b) Затем с помощью конструктора ImageTable.from_table превратите уже соединенную таблицу в ImageTable для дальнейшей работы с ней.

# %%
# a)
# Ваш код здесь
s.dljoin(annotatedTable = images , table = points_table , casOut = dict(name='merged_tbl', replace=True) , id = '_filename_0')
merged_table = s.CASTable('merged_tbl')
merged_table.head(50)
# Out:
# Selected Rows from Table MERGED_TBL
#
#          _filename_0    Var1  left_eye_x  left_eye_y  right_eye_x  \
# 0   10000150_006.jpg  1952.0    0.415039    0.376025     0.583984
# 1   10000150_012.jpg  1953.0    0.357247    0.301758     0.572474
# 2   10000150_013.jpg  1954.0    0.715820    0.405564     0.787109
# 3   10000150_014.jpg  1955.0    0.400433    0.232000     0.528139
# 4   10000150_017.jpg  1956.0    0.374000    0.418667     0.502000
# 5   10000150_020.jpg  1957.0    0.468750    0.235412     0.528320
# 6   10000150_029.jpg  1958.0    0.346000    0.514667     0.464000
# 7   10000151_004.jpg  1959.0    0.395480    0.266000     0.627119
# 8   10000151_005.jpg  1960.0    0.397531    0.370000     0.654321
# 9   10000151_007.jpg  1961.0    0.588000    0.538667     0.642000
# 10  10000151_013.jpg  1962.0    0.473633    0.520908     0.677734
# 11  10000151_016.jpg  1963.0    0.340820    0.278261     0.427734
# 12  10000151_017.jpg  1964.0    0.660156    0.289340     0.784180
# 13  10000151_020.jpg  1965.0    0.486000    0.600601     0.610000
# 14  10000151_022.jpg  1966.0    0.429333    0.286000     0.584000
# 15  10000151_024.jpg  1967.0    0.368490    0.501953     0.601562
# 16  10000151_025.jpg  1968.0    0.494000    0.370000     0.580000
# 17  10000151_027.jpg  1969.0    0.633789    0.398085     0.682617
# 18  10000152_001.jpg  1970.0    0.404706    0.583851     0.569412
# 19  10000152_008.jpg  1971.0    0.392000    0.393393     0.518000
# 22      0.695833      0.465823
# 23      0.645094      0.406000
# 24      0.416918      0.276000
# 25      0.766000      0.314667
# 26      0.607422      0.506716
# 27      0.577023      0.719727
# 28      0.900000      0.456000
# 29      0.562500      0.476608
# 30      0.596000      0.250667
# 31      0.644000      0.274667
# 32      0.696000      0.355670
# 33      0.670000      0.381333
# 34      0.642000      0.324324
# 35      0.770508      0.248902
# 36      0.724000      0.337423
# 37      0.654472      0.450000
# 38      0.484000      0.417417
# 39      0.486000      0.189333
# 40      0.396000      0.234667
# 41      0.408000      0.189333
# 42      0.584000      0.376238
# 43      0.614000      0.342342
# 44      0.564815      0.395062
# 45      0.561198      0.191406
# 46      0.636000      0.306667
# 47      0.735677      0.323242
# 48      0.592000      0.240000
# 49      0.884000      0.502525
#
#                                               _image_  _label_  _id_
# 0   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2128
# 1   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2132
# 2   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2133
# 3   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2134
# 4   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2135
# 5   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2136
# 6   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2137
# 7   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2139
# 8   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2140
# 9   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2141
# 10  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2143
# 11  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2144
# 12  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2145
# 13  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2146
# 14  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2147
# 15  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2148
# 16  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2149
# 17  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2150
# 18  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2151
# 19  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2152
# 20  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2153
# 21  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2154
# 22  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2155
# 23  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2156
# 24  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2157
# 25  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2158
# 26  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2159
# 27  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2160
# 28  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2161
# 29  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           2162
# 30  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           4135
# 31  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           4136
# 32  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           4137
# 33  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           4139
# 34  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           4140
# 35  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           4141
# 36  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           3598
# 37  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           3599
# 38  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           3600
# 39  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           3601
# 40  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           3602
# 41  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           3603
# 42  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           8389
# 43  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           8390
# 44  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           8391
# 45  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           8392
# 46  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           9169
# 47  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x02...           9170
# 48  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           9171
# 49  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...           9172
#
# [50 rows x 23 columns]

# %%
# b)
imgTbl = ImageTable.from_table(s.CASTable('merged_tbl') , image_col = '_image_' ,columns = keypoints_names)
imgTbl.tail(20)
# Out:
# Selected Rows from Table IMAGEDATA_NK5UDP
#
#                                                 _image_ _label_  \
# 8985  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8986  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8987  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8988  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8989  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8990  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8991  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8992  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8993  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8994  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8995  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8996  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8997  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8998  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 8999  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 9000  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 9001  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 9002  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 9003  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 9004  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
#
#            _filename_0  _id_  left_eye_x  left_eye_y  right_eye_x  \
# 8985  00000084_010.jpg   581    0.522000    0.498667     0.670000
# 8986  00000340_028.jpg   942    0.466000    0.429333     0.684000
# 8987  00000092_016.jpg   626    0.718000    0.320930     0.788000
# 8988  00000347_001.jpg   984    0.558000    0.536000     0.538000
# 8989  00000447_015.jpg  1644    0.452000    0.420000     0.586000
# 8990  00000089_016.jpg   608    0.614925    0.300000     0.734328
# 8991  40000917_024.jpg  6018    0.346000    0.279133     0.456000
# 8992  00000304_018.jpg   710    0.398000    0.570571     0.586000
# 8997     0.166000     0.381963      0.266000      0.204244      0.246000
# 8998     0.178000     0.226667      0.356000      0.192000      0.468000
# 8999     0.612000     0.128655      0.700000      0.169591      0.794000
# 9000     0.680664     0.307292      0.726562      0.307292      0.765625
# 9001     0.256836     0.104925      0.302734      0.109208      0.333008
# 9002     0.286445     0.256000      0.391304      0.270000      0.473146
# 9003     0.536458     0.539062      0.671875      0.557617      0.757812
# 9004     0.556000     0.237237      0.592000      0.231231      0.626000
#
#       right_ear2_y  right_ear3_x  right_ear3_y
# 8985      0.130667      0.796000      0.461333
# 8986      0.093333      0.798000      0.397333
# 8987      0.051163      0.814000      0.241860
# 8988      0.818667      0.572000      0.794667
# 8989      0.212000      0.672000      0.366000
# 8990      0.176000      0.814925      0.270000
# 8991      0.048780      0.544000      0.184282
# 8992      0.099099      0.712000      0.420420
# 8993      0.047722      0.746000      0.342733
# 8994      0.272230      0.892578      0.329685
# 8995      0.229381      0.479492      0.337629
# 8996      0.119141      0.558594      0.210938
# 8997      0.047745      0.348000      0.169761
# 8998      0.002667      0.462000      0.290667
# 8999      0.128655      0.740000      0.263158
# 9000      0.272135      0.762695      0.334635
# 9001      0.094218      0.324219      0.154176
# 9002      0.246000      0.445013      0.322000
# 9003      0.520508      0.723958      0.606445
# 9004      0.141141      0.644000      0.255255
#
# [20 rows x 22 columns]

# %% [markdown]
# **Задание 3: Подготовка данных для обучения**<br><br>
# а) Измените размер изображений на 96x96 с помощью функции resize ImageTable.<br>
# b) Перемешайте данные с помощью функции action shuffle.<br>
# c) Разделите набор данных на обучающий, валидационный и тестовых с помощью функции three_way_split. Процент данных в валидационном наборе данных - 20%, в тестовом - 20%.<br>

# %%
# a)
resized_imgTbl = imgTbl.resize(width = 96, height = 96, inplace = False, columns = keypoints_names)
resized_imgTbl.image_summary
resized_imgTbl.tail(20)
# Out:
# Selected Rows from Table IMAGEDATA_X0DWAO
#
#            _filename_0  right_ear3_x  right_eye_y   mouth_x   mouth_y  \
# 8985  10000256_006.jpg      0.729492     0.563690  0.477539  0.836018
# 8986  30000807_006.jpg      0.536000     0.418667  0.402000  0.448000
# 8987  60001339_005.jpg      0.861333     0.356000  0.512000  0.528000
# 8988  10000189_024.jpg      0.454819     0.308000  0.343373  0.352000
# 8989  00000092_013.jpg      0.748000     0.392000  0.672000  0.450667
# 8990  40001010_004.jpg      0.694000     0.370023  0.568000  0.557377
# 8991  20000519_010.jpg      0.708008     0.528646  0.655273  0.738281
# 8992  40001027_006.jpg      0.428000     0.365333  0.310000  0.496000
# 8993  50001193_005.jpg      0.500000     0.381333  0.388000  0.480000
# 8994  10000164_026.jpg      0.855856     0.436000  0.549550  0.560000
# 8995  20000645_005.jpg      0.463043     0.354000  0.734783  0.332000
# 8996  50001245_005.jpg      0.630000     0.418667  0.480000  0.584000
# 8997  60001424_021.jpg      0.849609     0.325521  0.754883  0.377604
# 8998  20000503_011.jpg      0.624000     0.294294  0.530000  0.423423
# 9003    0.546667    0.498000      0.685333      0.462000      0.498000
# 9004    0.526000    0.303303      0.592000      0.231231      0.255255
#
#       left_ear2_x  left_ear3_y  \
# 8985     0.246094     0.248902
# 8986     0.364000     0.264000
# 8987     0.216000     0.236000
# 8988     0.259036     0.232000
# 8989     0.570000     0.344000
# 8990     0.264000     0.166276
# 8991     0.305664     0.414062
# 8992     0.126000     0.202667
# 8993     0.240000     0.237333
# 8994     0.276276     0.298000
# 8995     0.541304     0.530000
# 8996     0.300000     0.192000
# 8997     0.749023     0.214844
# 8998     0.250000     0.231231
# 8999     0.452000     0.149510
# 9000     0.600000     0.260000
# 9001     0.360000     0.229333
# 9002     0.064000     0.530667
# 9003     0.533333     0.434000
# 9004     0.522000     0.237237
#
#                                                 _image_  _id_ _label_
# 8985  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  3002
# 8986  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  5151
# 8987  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  8886
# 8988  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  2459
# 8989  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...   625
# 8990  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  6643
# 8991  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  3528
# 8992  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  6764
# 8993  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  7922
# 8994  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  2247
# 8995  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  4608
# 8996  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  8304
# 8997  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  9459
# 8998  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  3369
# 8999  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  1642
# 9000  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  8762
# 9001  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  4857
# 9002  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  6694
# 9003  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  5700
# 9004  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  5221
#
# [20 rows x 22 columns]

# %%
# b)
# Ваш код здесь
s.shuffle(table = resized_imgTbl , casOut = dict(name='shuffled_tbl', replace=True))

print(s.CASTable('shuffled_tbl').numrows()["numrows"])
s.CASTable('shuffled_tbl').head(10)
# Out:
# 9005
# Selected Rows from Table SHUFFLED_TBL
#
#         _filename_0  right_ear3_x  right_eye_y   mouth_x   mouth_y  \
# 0  10000161_014.jpg      0.486486     0.270000  0.339339  0.344000
# 1  60001496_009.jpg      0.660661     0.184000  0.501502  0.244000
# 2  50001163_003.jpg      0.886000     0.327327  0.746000  0.423423
# 3  60001317_000.jpg      0.716000     0.420420  0.538000  0.591592
# 4  60001464_023.jpg      0.690808     0.258789  0.512535  0.333984
# 5  20000671_028.jpg      0.896000     0.433121  0.766000  0.570064
# 6  00000393_022.jpg      0.710000     0.767442  0.554000  0.909561
# 7  60001465_000.jpg      0.592000     0.418667  0.516000  0.594667
# 8  10000186_024.jpg      0.604492     0.485677  0.413086  0.623698
# 9  00000348_002.jpg      0.588000     0.525526  0.490000  0.624625
#
#    left_ear1_y  left_ear1_x  left_ear3_x  right_ear2_x  left_ear2_y  ...  \
# 0     0.226000     0.189189     0.276276      0.504505     0.128000  ...
# 1     0.190000     0.309309     0.414414      0.645646     0.060000  ...
# 2     0.216216     0.632000     0.720000      0.924000     0.033033  ...
# 3     0.321321     0.422000     0.494000      0.724000     0.078078  ...
# 4     0.263672     0.299443     0.427577      0.679666     0.089844  ...
# 5     0.292994     0.634000     0.728000      0.914000     0.089172  ...
# 6     0.687339     0.392000     0.480000      0.772000     0.509044  ...
# 7     0.357333     0.262000     0.430000      0.612000     0.066667  ...
# 8     0.279948     0.374023     0.466797      0.605469     0.102865  ...
# 9     0.492492     0.350000     0.402000      0.560000     0.330330  ...
#
#    left_eye_x  left_eye_y  right_ear1_x  right_ear1_y  right_ear3_y  \
# 0    0.270270    0.268000      0.399399      0.184000      0.226000
# 1    0.408408    0.188000      0.549550      0.122000      0.182000
# 2    0.706000    0.297297      0.820000      0.183183      0.291291
# 3    0.486000    0.414414      0.632000      0.234234      0.330330
# 4    0.427577    0.261719      0.564067      0.176758      0.256836
# 5    0.716000    0.410828      0.824000      0.245223      0.350318
# 6    0.488000    0.762274      0.636000      0.596899      0.702842
# 7    0.398000    0.424000      0.502000      0.253333      0.357333
# 8    0.382812    0.457031      0.535156      0.234375      0.343750
# 9    0.428000    0.555556      0.508000      0.360360      0.420420
#
#    left_ear2_x  left_ear3_y  \
# 0     0.174174     0.184000
# 1     0.300300     0.122000
# 2     0.658000     0.156156
# 3     0.394000     0.225225
# 4     0.281337     0.175781
# 5     0.656000     0.226115
# 6     0.356000     0.591731
# 7     0.294000     0.253333
# 8     0.339844     0.214844
# 9     0.330000     0.393393
#
#                                              _image_  _id_ _label_
# 0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  2219
# 1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  9970
# 2  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  7709
# 3  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  8756
# 4  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  9742
# 5  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  4853
# 6  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  1307
# 7  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  9744
# 8  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  2431
# 9  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...   991
#
# [10 rows x 22 columns]

# %%
# c)
# Ваш код здесь
train_data, val_data, test_data = three_way_split(s.CASTable('shuffled_tbl'), valid_rate=20, test_rate=20, seed = 42, im_table = False)

print("Number of images in train_data:", train_data.numrows()["numrows"])
print("Number of images in validation_data:", val_data.numrows()["numrows"])
print("Number of images in test_data:", test_data.numrows()["numrows"])
train_data.head(10)
# Out:
# Number of images in train_data: 5403
# Number of images in validation_data: 1801
# Number of images in test_data: 1801
# Selected Rows from Table TRAIN_IYM0UY
#
#         _filename_0  right_ear3_x  right_eye_y   mouth_x   mouth_y  \
# 0  20000549_024.jpg      0.690000     0.314667  0.604000  0.402667
# 1  40001038_014.jpg      0.610352     0.370262  0.566406  0.486880
# 2  60001314_011.jpg      0.385742     0.464730  0.309570  0.553250
# 3  60001384_013.jpg      0.754000     0.594667  0.694000  0.637333
# 4  40000941_016.jpg      0.494000     0.150602  0.406000  0.207831
# 5  40001065_018.jpg      0.858398     0.204027  0.738281  0.288591
# 6  00000349_021.jpg      0.864000     0.492492  0.642000  0.750751
# 7  00000079_026.jpg      0.651367     0.453039  0.501953  0.638122
# 8  60001309_004.jpg      0.472000     0.344311  0.336000  0.458084
# 9  40001043_025.jpg      0.640000     0.466667  0.516000  0.589333
#
#    left_ear1_y  left_ear1_x  left_ear3_x  right_ear2_x  left_ear2_y  ...  \
# 0     0.234667     0.496000     0.570000      0.728000     0.098667  ...
# 1     0.462099     0.423828     0.443359      0.520508     0.309038  ...
# 2     0.439834     0.207031     0.240234      0.402344     0.356846  ...
# 3     0.424000     0.632000     0.706000      0.834000     0.312000  ...
# 4     0.150602     0.370000     0.400000      0.484000     0.054217  ...
# 5     0.163758     0.683594     0.726562      0.853516     0.036242  ...
# 6     0.489489     0.350000     0.476000      0.860000     0.114114  ...
# 7     0.379834     0.326172     0.405273      0.672852     0.168508  ...
# 8     0.263473     0.212000     0.268000      0.492000     0.131737  ...
# 9     0.373333     0.400000     0.488000      0.642000     0.224000  ...
#
#    left_eye_x  left_eye_y  right_ear1_x  right_ear1_y  right_ear3_y  \
# 0    0.562000    0.298667      0.650000      0.202667      0.272000
# 1    0.497070    0.435860      0.513672      0.250729      0.288630
# 2    0.257812    0.471646      0.333984      0.380360      0.431535
# 3    0.696000    0.536000      0.768000      0.506667      0.586667
# 4    0.388000    0.159639      0.446000      0.090361      0.135542
# 5    0.712891    0.206711      0.799805      0.091275      0.163758
# 6    0.508000    0.513514      0.686000      0.258258      0.441441
# 7    0.416016    0.465470      0.569336      0.266575      0.366022
# 8    0.288000    0.344311      0.404000      0.197605      0.263473
# 9    0.468000    0.461333      0.572000      0.317333      0.384000
#
#    left_ear2_x  left_ear3_y  \
# 0     0.522000     0.189333
# 1     0.360352     0.317784
# 2     0.193359     0.384509
# 3     0.696000     0.424000
# 4     0.366000     0.096386
# 5     0.661133     0.091275
# 6     0.284000     0.276276
# 7     0.286133     0.274862
# 8     0.178000     0.197605
# 9     0.422000     0.314667
#
#                                              _image_  _id_ _label_
# 0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  3805
# 1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  6832
# 2  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  8737
# 3  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  9161
# 4  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  6176
# 5  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  7042
# 6  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  1002
# 7  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...   564
# 8  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  8700
# 9  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  6865
#
# [10 rows x 22 columns]

# %% [markdown]
# **Задание 4: Построение модели**<br><br>
# Постройте модель CNN, схема которой изображена на картинке. Особенности модели не отраженные на рисунке: в слое Conv предшествующем BatchNormalization отсутствуют bias, а в Dense слое присутствует дропаут с вероятностью 0.2. Полученная вами сеть должна показывать Loss Error на тестовом наборе данных более 0.21.
# ![model](kpnetwork.PNG)

# %%
model = Sequential(s, model_table='cnn_model')
model.add(InputLayer(1,96,96, name = 'input'))
# Ваш код здесь
model.add(Conv2d(72,4))
model.add(Pooling(2))
model.add(Conv2d(48,2,include_bias=False))
model.add(BN())
model.add(Dense(48, dropout = 0.2))
model.add(Keypoints(n=18, name='kp1'))
model.print_summary()
# Out:
# NOTE: Input layer added.
# NOTE: Convolution layer added.
# NOTE: Pooling layer added.
# NOTE: Convolution layer added.
# NOTE: Batch normalization layer added.
# NOTE: Fully-connected layer added.
# NOTE: Keypoints layer added.
# NOTE: Model compiled successfully.
#   Layer Id    Layer       Type   Kernel Size  Stride Activation   Output Size  \
# 0        0    input      input                             None   (96, 96, 1)
# 1        1  Convo.1      convo        (4, 4)  (1, 1)       Relu  (96, 96, 72)
# 2        2    Pool1       pool        (2, 2)  (2, 2)        Max  (48, 48, 72)
# 3        3  Convo.2      convo        (2, 2)  (1, 1)       Relu  (48, 48, 48)
# 4        4    B.N.1  batchnorm                             Auto  (48, 48, 48)
# 5        5    F.C.1         fc  (110592, 48)               Relu            48
# 6        6      kp1  keypoints      (48, 18)               Auto            18
# 7
# 8  Summary
#
#          Number of Parameters FLOPS(forward pass)
# 0                      (0, 0)                   0
# 1                  (1152, 72)            10616832
# 2                      (0, 0)                   0
# 3                  (13824, 0)            31850496
# 4                     (0, 96)                   0
# 5                (5308416, 0)             5308416
# 6                   (864, 18)                   0
# 7  Total number of parameters         Total FLOPS
# 8                   5,324,442          47,775,744

# %% [markdown]
# **Задание 5: Обучение модели**<br><br>
# Обучите модель, дополнив код ниже. Формат входных данных в model.fit укажите с помощью параметра data_specs.

# %%
from dlpy.model import *
from dlpy.model import Optimizer

#Подберите самостоятельно
lr_ = 0.001

optimizer = Optimizer(mini_batch_size=12, log_level=2, max_epochs=20, reg_l2=0.0005,
                      algorithm=MomentumSolver(clip_grad_max=1000, clip_grad_min=-1000,
                                               learning_rate=lr_, step_size=30))

dataOpts = [DataSpec(type_='IMAGE', layer='input', data=['_image_']),DataSpec(type_='numnom', layer='kp1', data=keypoints_names)]
train_history = model.fit(data = train_data , data_specs = dataOpts, valid_table = val_data, lr = lr_ , optimizer = optimizer,
                         record_seed=13309 ,seed=42)
# Out:
# NOTE: Training from scratch.
# WARNING: Using dataSpecs settings. Additional input or target option settings will be ignored.
# WARNING: The source layer convo.2 to batch normalization layer b.n.1 does not have an IDENTITY activation function.
# NOTE:  Synchronous mode is enabled.
# NOTE:  The total number of parameters is 5324490.
# NOTE:  The approximate memory cost is 5153.00 MB.
# NOTE:  Loading weights cost       0.00 (s).
# NOTE:  Initializing each layer cost       0.70 (s).
# NOTE:  The total number of threads on each worker is 40.
# NOTE:  The total mini-batch size per thread on each worker is 12.
# NOTE:  The maximum mini-batch size across all workers for the synchronous mode is 480.
# NOTE:  Number of input variables:     1
# NOTE:  Number of numeric input variables:      1
# NOTE:  Epoch Learning Rate        Loss  Fit Error  Validation Loss Validation Error   Time(s)
# NOTE:  0         0.001            2.98      5.961            1.753            3.505    22.47
# NOTE:  1         0.001           1.649      3.299            1.458            2.916    22.34
# NOTE:  2         0.001           1.333      2.666            1.176            2.352    22.01
# NOTE:  3         0.001           1.077      2.153           0.9445            1.889    22.50
# NOTE:  4         0.001          0.8567      1.713           0.7631            1.526    22.13
# NOTE:  5         0.001          0.7012      1.402           0.6234            1.247    22.24
# NOTE:  6         0.001          0.5771      1.154           0.5161            1.032    21.84
# NOTE:  7         0.001          0.4732     0.9465           0.4342           0.8685    21.68
# NOTE:  8         0.001          0.4048     0.8096           0.3717           0.7434    22.20
# NOTE:  9         0.001          0.3445      0.689           0.3241           0.6483    21.93
# NOTE:  10        0.001          0.3126     0.6252           0.2876           0.5752    21.13
# NOTE:  11        0.001          0.2747     0.5493           0.2595            0.519    21.87
# NOTE:  12        0.001          0.2503     0.5006           0.2383           0.4766    21.77
# NOTE:  13        0.001          0.2299     0.4597           0.2222           0.4443    21.40
# NOTE:  14        0.001          0.2166     0.4333           0.2097           0.4194    22.01
# NOTE:  15        0.001          0.2022     0.4044           0.2004           0.4008    42.43
# NOTE:  16        0.001          0.1956     0.3912           0.1933           0.3866    42.39
# NOTE:  17        0.001          0.1879     0.3758           0.1879           0.3757    41.74
# NOTE:  18        0.001          0.1858     0.3716           0.1838           0.3675    42.30
# NOTE:  19        0.001          0.1807     0.3614           0.1807           0.3615    43.10
# NOTE:  The optimization reached the maximum number of epochs.
# NOTE:  The total time is     541.49 (s).

# %% [markdown]
# **Задание 6: Проверка и визуализация результатов работы сети**<br><br>
# a) Получите предсказания на тестовом наборе данных c помощью функции predict.<br>
# b) Дополните код функции plot_landmarks, предназначенной для визуализации предсказаний модели. С помощью вызова этой функции отоборазите результаты из тестового набора данных.

# %%
# a)
# Ваш код здесь
model.predict(data=test_data)
# Out:
# [ScoreInfo]
#
#                           Descr         Value
#  0  Number of Observations Read          1801
#  1  Number of Observations Used          1801
#  2           Mean Squared Error      0.366167
#  3                   Loss Error      0.183083
#
# [OutputCasTables]
#
#             casLib              Name  Rows  Columns  \
#  0  CASUSER(msu95)  Valid_Res_89sAje  1801       40
#
#                                              casTable
#  0  CASTable('Valid_Res_89sAje', caslib='CASUSER(m...
#
# + Elapsed: 5.52s, user: 72.5s, sys: 9.54s, mem: 1.85e+03mb

# %%
# b)
def plot_landmarks(conn, data, targets, image_list=range(4), n_col=2, figsize=None):
    import cv2
    n_images = len(image_list)
    num_obs = min(len(data), n_images)
    res_img = conn.fetchimages(table=data, to=num_obs).Images
    res_label = conn.fetch(data, fetchvars=targets, to=num_obs).Fetch

    if n_images > n_col:
        n_row = n_images // n_col + 1
    else:
        n_row = 1
        n_col = n_images

    if figsize is None:
        figsize = (16, 16 // n_col * n_row)

    fig = plt.figure(figsize=figsize)

    idx_img = 1
    for i in image_list:
        # Ваш код здесь
        img = res_img.loc[i, 'Image']
        img_arr = np.array(img)
        circle_size = int(min(img_arr.shape[:2])/80)
        for k in range(0, len(targets), 2):
            x = int(res_label.loc[i, targets[k]] * res_img.loc[i, 'Width']/2 + res_label.loc[i, targets[k]]*res_img.loc[i, 'Width']/2)
            y = int(res_label.loc[i, targets[k + 1]] * res_img.loc[i, 'Height']/2 + res_label.loc[i, targets[k + 1]] * res_img.loc[i, 'Height']/2)
            cv2.circle(img_arr, (x, y), circle_size, (255, 0, 0), -1)
        ax = fig.add_subplot(n_row, n_col, idx_img)
        plt.imshow(img_arr, cmap='gray')
        idx_img = idx_img + 1
        plt.xticks([]), plt.yticks([])
    plt.show()

# %%
#plot_landmarks(s, model.valid_res_tbl, targets=keypoints_names, image_list=range(27), n_col=3)
plot_landmarks(s, model.valid_res_tbl, targets=keypoints_names, image_list=range(36), n_col=4)
# Out:
# NOTE: Table VALID_RES_89SAJE contains compressed images.

# %% [markdown]
# **Задание 7 (дополнительное):**<br><br>
# Перепишите функцию plot_landmarks так, чтобы различные ключевые точки отображались различными цветами. То есть, например, точка левого глаза всегда была синей, правого - зеленой и т.д.

# %%
#Ваш код здесь
